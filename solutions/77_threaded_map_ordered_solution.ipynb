# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/77_threaded_map_ordered_solution.ipynb)
#
# # 🟡 Solution: Ordered Threaded Map
#
# Reference solution for `threaded_map_ordered`.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
# ✅ SOLUTION

def threaded_map(fn, items, max_workers: int = 4):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        return list(executor.map(fn, items))

# %%
# Verify
print(threaded_map(lambda x: x * x, range(5), max_workers=2))

# %%
# Run judge
from torch_judge import check
check('threaded_map_ordered')
