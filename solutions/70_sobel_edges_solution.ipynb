# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/70_sobel_edges_solution.ipynb)
#
# # 🟡 Solution: Sobel Edge Magnitude
#
# Reference solution for `sobel_edges`.

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✅ SOLUTION

def sobel_edges(x: torch.Tensor, eps: float = 1e-6) -> torch.Tensor:
    B, C, H, W = x.shape
    kx = torch.tensor([[-1., 0., 1.], [-2., 0., 2.], [-1., 0., 1.]], device=x.device, dtype=x.dtype)
    ky = torch.tensor([[-1., -2., -1.], [0., 0., 0.], [1., 2., 1.]], device=x.device, dtype=x.dtype)
    kx = kx.view(1, 1, 3, 3).repeat(C, 1, 1, 1)
    ky = ky.view(1, 1, 3, 3).repeat(C, 1, 1, 1)
    gx = F.conv2d(x, kx, padding=1, groups=C)
    gy = F.conv2d(x, ky, padding=1, groups=C)
    return torch.sqrt(gx.pow(2) + gy.pow(2) + eps)

# %%
# Verify
x = torch.randn(2, 3, 8, 8)
print(sobel_edges(x).shape)

# %%
# Run judge
from torch_judge import check
check('sobel_edges')
