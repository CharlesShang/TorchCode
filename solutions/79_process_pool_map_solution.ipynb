# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/79_process_pool_map_solution.ipynb)
#
# # 🟡 Solution: Process Pool Map
#
# Reference solution for `process_pool_map`.

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
from concurrent.futures import ProcessPoolExecutor
import multiprocessing as mp

# %%
# ✅ SOLUTION

def process_pool_map(fn, items, max_workers: int | None = None, chunksize: int = 1):
    try:
        ctx = mp.get_context("fork")
        with ProcessPoolExecutor(max_workers=max_workers, mp_context=ctx) as executor:
            return list(executor.map(fn, items, chunksize=chunksize))
    except ValueError:
        with ProcessPoolExecutor(max_workers=max_workers) as executor:
            return list(executor.map(fn, items, chunksize=chunksize))

# %%
# Verify
print(process_pool_map(abs, [-1, 2, -3], max_workers=2))

# %%
# Run judge
from torch_judge import check
check('process_pool_map')
