# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/73_video_uniform_temporal_sample.ipynb)
#
# # 🟡 Medium: Video Uniform Temporal Sampling
#
# Implement uniform temporal sampling for video tensors.
#
# ### Signature
# ```python
# def uniform_temporal_sample(video: torch.Tensor, num_frames: int,
#                             temporal_dim: int = 0) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Select `num_frames` evenly spaced frames from the temporal dimension
# - Use rounded `linspace(0, T - 1, num_frames)` indices
# - Support both unbatched `(T, C, H, W)` and batched `(B, T, C, H, W)` by setting `temporal_dim`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def uniform_temporal_sample(video: torch.Tensor, num_frames: int,
                            temporal_dim: int = 0) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
video = torch.arange(10 * 1 * 1 * 1).view(10, 1, 1, 1)
print(uniform_temporal_sample(video, 4).flatten())

# %%
# ✅ SUBMIT
from torch_judge import check
check('video_uniform_temporal_sample')
