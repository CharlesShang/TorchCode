# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/42_label_smoothing.ipynb)
#
# # 🟡 Medium: Label Smoothing Loss
#
# Implement **cross-entropy with label smoothing** from scratch.
#
# For each example, the target class gets confidence `1 - ε`, and the remaining smoothing mass is spread across the full class distribution via the average negative log-probability:
#
# $$	ext{loss} = (1 - \epsilon)(-\log p_y) + \epsilon \cdot rac{1}{C}\sum_j -\log p_j$$
#
# ### Signature
# ```python
# def label_smoothing_loss(
#     logits: torch.Tensor,
#     targets: torch.Tensor,
#     smoothing: float = 0.1,
#     reduction: str = "mean",
# ) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - `logits`: shape `(B, C)`
# - `targets`: shape `(B,)`, class indices
# - Support `reduction="mean"`, `"sum"`, and `"none"`
# - Do **NOT** use `F.cross_entropy`, `nn.CrossEntropyLoss`, or `F.log_softmax`
# - Must be numerically stable with large logits
#
# ### Hint
# Use `torch.logsumexp` to build stable log-probabilities.

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def label_smoothing_loss(logits: torch.Tensor, targets: torch.Tensor,
                         smoothing: float = 0.1, reduction: str = "mean") -> torch.Tensor:
    pass  # Compute stable log_probs, NLL, smooth loss, then reduce

# %%
# 🧪 Debug
logits = torch.randn(4, 10)
targets = torch.randint(0, 10, (4,))
print("Smoothed loss:", label_smoothing_loss(logits, targets, smoothing=0.1))
print("CE ref:       ", F.cross_entropy(logits, targets))
print("Per-example:  ", label_smoothing_loss(logits, targets, smoothing=0.1, reduction="none"))

# %%
# ✅ SUBMIT
from torch_judge import check
check('label_smoothing')
