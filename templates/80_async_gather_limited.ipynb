# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/80_async_gather_limited.ipynb)
#
# # 🟡 Medium: Async Gather with Concurrency Limit
#
# Implement `asyncio.gather` with a concurrency limit.
#
# ### Signature
# ```python
# async def async_gather_limited(coros, limit: int):
#     ...
# ```
#
# ### Requirements
# - Run awaitables concurrently, but no more than `limit` at a time
# - Preserve input order in the returned list
# - Propagate exceptions from any coroutine
# - Use `asyncio.Semaphore`

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import asyncio

# %%
# ✏️ YOUR IMPLEMENTATION HERE

async def async_gather_limited(coros, limit: int):
    pass

# %%
# 🧪 Debug

def run_async(coro):
    import asyncio
    import threading
    box = {}
    def target():
        try:
            box['value'] = asyncio.run(coro)
        except BaseException as e:
            box['error'] = e
    t = threading.Thread(target=target)
    t.start()
    t.join(timeout=5)
    if t.is_alive():
        raise TimeoutError('async test timed out')
    if 'error' in box:
        raise box['error']
    return box.get('value')

async def work(x):
    await asyncio.sleep(0.01)
    return x * x
print(run_async(async_gather_limited([work(i) for i in range(5)], limit=2)))

# %%
# ✅ SUBMIT
from torch_judge import check
check('async_gather_limited')
