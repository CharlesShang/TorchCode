# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/69_bilinear_resize.ipynb)
#
# # 🟡 Medium: Bilinear Resize NCHW
#
# Implement bilinear image resizing for NCHW tensors.
#
# ### Signature
# ```python
# def bilinear_resize(x: torch.Tensor, out_h: int, out_w: int,
#                     align_corners: bool = False) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Input shape is `(B, C, H, W)`
# - Output shape is `(B, C, out_h, out_w)`
# - Support `align_corners=False` and `align_corners=True`
# - Do **NOT** use `torch.nn.functional.interpolate` in your implementation

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def bilinear_resize(x: torch.Tensor, out_h: int, out_w: int,
                    align_corners: bool = False) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
x = torch.randn(2, 3, 5, 7)
y = bilinear_resize(x, 9, 4)
print(y.shape)
print((y - F.interpolate(x, size=(9, 4), mode='bilinear', align_corners=False)).abs().max())

# %%
# ✅ SUBMIT
from torch_judge import check
check('bilinear_resize')
