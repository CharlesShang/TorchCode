# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/57_rope_scaling.ipynb)
#
# # 🟡 Medium: RoPE Scaling
#
# Implement **linear RoPE scaling** for long-context LLMs.
#
# ### Signature
# ```python
# def apply_scaled_rope(x: torch.Tensor, positions: torch.Tensor | None = None,
#                       base: float = 10000.0, scaling_factor: float = 1.0) -> torch.Tensor:
#     ...
# ```
#
# ### Input
# `x` shape is `(..., S, D)` and `D` must be even.
#
# ### Requirements
# - If `positions is None`, use `0..S-1`
# - Divide positions by `scaling_factor` before computing angles
# - Apply standard pairwise rotary embedding
# - Preserve shape and per-token norms

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def apply_scaled_rope(x: torch.Tensor, positions: torch.Tensor | None = None,
                      base: float = 10000.0, scaling_factor: float = 1.0) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
x = torch.randn(2, 4, 8)
y = apply_scaled_rope(x, scaling_factor=2.0)
print(y.shape)
print(torch.allclose(y.norm(dim=-1), x.norm(dim=-1), atol=1e-5))

# %%
# ✅ SUBMIT
from torch_judge import check
check('rope_scaling')
