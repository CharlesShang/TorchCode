# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/82_async_retry.ipynb)
#
# # 🟡 Medium: Async Retry Helper
#
# Implement an async retry helper for flaky async operations.
#
# ### Signature
# ```python
# async def async_retry(fn, retries: int = 3, delay: float = 0.0,
#                       exceptions=(Exception,)):
#     ...
# ```
#
# ### Requirements
# - `fn` is a zero-argument async callable
# - Try once plus `retries` additional times
# - Sleep `delay` seconds between failed attempts
# - Retry only exceptions matching `exceptions`
# - Re-raise the final exception when all attempts fail

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import asyncio

# %%
# ✏️ YOUR IMPLEMENTATION HERE

async def async_retry(fn, retries: int = 3, delay: float = 0.0,
                      exceptions=(Exception,)):
    pass

# %%
# 🧪 Debug

def run_async(coro):
    import asyncio
    import threading
    box = {}
    def target():
        try:
            box['value'] = asyncio.run(coro)
        except BaseException as e:
            box['error'] = e
    t = threading.Thread(target=target)
    t.start()
    t.join(timeout=5)
    if t.is_alive():
        raise TimeoutError('async test timed out')
    if 'error' in box:
        raise box['error']
    return box.get('value')

state = {'n': 0}
async def flaky():
    state['n'] += 1
    if state['n'] < 3:
        raise RuntimeError('try again')
    return 'ok'
print(run_async(async_retry(flaky, retries=3)))

# %%
# ✅ SUBMIT
from torch_judge import check
check('async_retry')
