# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/52_rectified_flow_loss.ipynb)
#
# # 🟡 Medium: Rectified Flow Loss
#
# Implement the **rectified flow / flow matching loss** used by modern text-to-image systems.
#
# ### Signature
# ```python
# def rectified_flow_loss(model, x0: Tensor, x1: Tensor, t: Tensor | None = None,
#                         reduction: str = "mean") -> Tensor:
#     ...
# ```
#
# ### Requirements
# - `x0`: noise/data start point
# - `x1`: clean/data endpoint
# - If `t is None`, sample `t ~ Uniform(0, 1)` with shape `(B,)`
# - Interpolate `x_t = (1 - t) * x0 + t * x1`
# - Target velocity is `x1 - x0`
# - Model is called as `model(x_t, t)`
# - Support `reduction="mean"`, `"sum"`, and `"none"`

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def rectified_flow_loss(model, x0: torch.Tensor, x1: torch.Tensor,
                        t: torch.Tensor | None = None, reduction: str = "mean") -> torch.Tensor:
    pass

# %%
# 🧪 Debug
class ZeroModel:
    def __call__(self, x, t):
        return torch.zeros_like(x)

x0 = torch.zeros(2, 3)
x1 = torch.ones(2, 3)
print(rectified_flow_loss(ZeroModel(), x0, x1, t=torch.tensor([0.25, 0.75])))

# %%
# ✅ SUBMIT
from torch_judge import check
check('rectified_flow_loss')
