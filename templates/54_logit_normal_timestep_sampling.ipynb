# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/54_logit_normal_timestep_sampling.ipynb)
#
# # 🟡 Medium: Logit-Normal Timestep Sampling
#
# Implement **logit-normal timestep sampling**, commonly used to bias flow/diffusion training toward useful noise levels.
#
# ### Signature
# ```python
# def sample_logit_normal_timesteps(batch_size: int, mean: float = 0.0, std: float = 1.0,
#                                   device=None, dtype=torch.float32, generator=None) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Draw `z ~ Normal(mean, std)`
# - Return `sigmoid(z)`, shape `(batch_size,)`
# - Values must be strictly between 0 and 1
# - Support `device`, `dtype`, and optional `torch.Generator`

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def sample_logit_normal_timesteps(batch_size: int, mean: float = 0.0, std: float = 1.0,
                                  device=None, dtype=torch.float32, generator=None) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
g = torch.Generator().manual_seed(0)
t = sample_logit_normal_timesteps(8, generator=g)
print(t)
print(t.min().item(), t.max().item())

# %%
# ✅ SUBMIT
from torch_judge import check
check('logit_normal_timestep_sampling')
