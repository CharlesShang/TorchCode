# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/76_thread_safe_counter.ipynb)
#
# # 🟢 Easy: Thread-Safe Counter
#
# Implement a thread-safe counter with a lock.
#
# ### Signature
# ```python
# class ThreadSafeCounter:
#     def __init__(self, initial: int = 0): ...
#     def increment(self, n: int = 1) -> int: ...
#     def value(self) -> int: ...
# ```
#
# ### Requirements
# - Use `threading.Lock`
# - `increment` must be safe when many threads call it at the same time
# - `value()` should return a consistent value under the same lock

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import threading

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class ThreadSafeCounter:
    def __init__(self, initial: int = 0):
        pass

    def increment(self, n: int = 1) -> int:
        pass

    def value(self) -> int:
        pass

# %%
# 🧪 Debug
counter = ThreadSafeCounter()
print(counter.increment())
print(counter.value())

# %%
# ✅ SUBMIT
from torch_judge import check
check('thread_safe_counter')
