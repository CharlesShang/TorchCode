# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/70_sobel_edges.ipynb)
#
# # 🟡 Medium: Sobel Edge Magnitude
#
# Implement Sobel edge magnitude for image tensors.
#
# ### Signature
# ```python
# def sobel_edges(x: torch.Tensor, eps: float = 1e-6) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Input shape is `(B, C, H, W)`
# - Apply Sobel X and Sobel Y independently per channel
# - Return edge magnitude with the same shape as input
# - Use zero padding of 1 pixel
# - You may use `F.conv2d`, but use grouped/depthwise convolution

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def sobel_edges(x: torch.Tensor, eps: float = 1e-6) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
x = torch.randn(2, 3, 8, 8)
print(sobel_edges(x).shape)

# %%
# ✅ SUBMIT
from torch_judge import check
check('sobel_edges')
