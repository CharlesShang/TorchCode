# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/78_bounded_blocking_queue.ipynb)
#
# # 🟡 Medium: Bounded Blocking Queue
#
# Implement a bounded blocking queue using condition variables.
#
# ### Signature
# ```python
# class BoundedBlockingQueue:
#     def __init__(self, capacity: int): ...
#     def put(self, item): ...
#     def get(self): ...
#     def qsize(self) -> int: ...
# ```
#
# ### Requirements
# - `put` blocks while the queue is full
# - `get` blocks while the queue is empty
# - Use `threading.Condition`
# - `qsize` should be thread-safe

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import threading
from collections import deque

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class BoundedBlockingQueue:
    def __init__(self, capacity: int):
        pass

    def put(self, item):
        pass

    def get(self):
        pass

    def qsize(self) -> int:
        pass

# %%
# 🧪 Debug
q = BoundedBlockingQueue(2)
q.put(1)
q.put(2)
print(q.get(), q.get(), q.qsize())

# %%
# ✅ SUBMIT
from torch_judge import check
check('bounded_blocking_queue')
