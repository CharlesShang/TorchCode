# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/63_multi_token_prediction_loss.ipynb)
#
# # 🟡 Medium: Multi-Token Prediction Loss
#
# Implement **multi-token prediction loss**, where each position predicts several future tokens.
#
# ### Signature
# ```python
# def multi_token_prediction_loss(logits: torch.Tensor, targets: torch.Tensor,
#                                 ignore_index: int = -100) -> torch.Tensor:
#     ...
# ```
#
# ### Input
# - `logits`: `(B, S, K, V)` where `K` is number of future-token heads
# - `targets`: `(B, S + K)`
#
# ### Requirement
# Head `k` predicts `targets[:, k+1 : k+1+S]` from every position.
# Use stable cross-entropy and ignore positions equal to `ignore_index`.

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def multi_token_prediction_loss(logits: torch.Tensor, targets: torch.Tensor,
                                ignore_index: int = -100) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
logits = torch.randn(2, 4, 3, 10)
targets = torch.randint(0, 10, (2, 7))
print(multi_token_prediction_loss(logits, targets))

# %%
# ✅ SUBMIT
from torch_judge import check
check('multi_token_prediction_loss')
