# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/72_non_max_suppression.ipynb)
#
# # 🟡 Medium: Non-Max Suppression
#
# Implement greedy non-max suppression for object detection.
#
# ### Signature
# ```python
# def non_max_suppression(boxes: torch.Tensor, scores: torch.Tensor,
#                         iou_threshold: float = 0.5) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Boxes use `(x1, y1, x2, y2)` format
# - Return kept indices as a 1-D long tensor
# - Indices should be in descending score order
# - Do not use `torchvision.ops.nms`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def non_max_suppression(boxes: torch.Tensor, scores: torch.Tensor,
                        iou_threshold: float = 0.5) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
boxes = torch.tensor([[0.,0.,2.,2.], [0.2,0.2,2.2,2.2], [5.,5.,6.,6.]])
scores = torch.tensor([0.9, 0.8, 0.7])
print(non_max_suppression(boxes, scores, 0.5))

# %%
# ✅ SUBMIT
from torch_judge import check
check('non_max_suppression')
