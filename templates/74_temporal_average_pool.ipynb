# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/74_temporal_average_pool.ipynb)
#
# # 🟡 Medium: Temporal Average Pooling for Video
#
# Implement average pooling over the temporal dimension of a video tensor.
#
# ### Signature
# ```python
# def temporal_avg_pool(video: torch.Tensor, kernel_size: int,
#                       stride: int | None = None, padding: int = 0) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Input shape is `(B, C, T, H, W)`
# - Pool only over `T`; keep `H` and `W` unchanged
# - If `stride is None`, use `stride = kernel_size`
# - Match `F.avg_pool3d(video, kernel_size=(k,1,1), stride=(s,1,1), padding=(p,0,0))`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def temporal_avg_pool(video: torch.Tensor, kernel_size: int,
                      stride: int | None = None, padding: int = 0) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
video = torch.randn(2, 3, 8, 4, 4)
print(temporal_avg_pool(video, 3, stride=2, padding=1).shape)

# %%
# ✅ SUBMIT
from torch_judge import check
check('temporal_average_pool')
