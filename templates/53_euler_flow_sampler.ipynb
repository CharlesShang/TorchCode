# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/53_euler_flow_sampler.ipynb)
#
# # 🟡 Medium: Euler Flow Sampler
#
# Implement a simple **Euler sampler** for rectified flow models.
#
# ### Signature
# ```python
# def euler_flow_sample(model, x0: torch.Tensor, steps: int = 20,
#                       return_trajectory: bool = False):
#     ...
# ```
#
# ### Requirements
# - Start at `x0` when `t=0`
# - Use fixed Euler step size `dt = 1 / steps`
# - At step `i`, call `model(x, t)` where `t` has shape `(B,)`
# - Update `x = x + dt * velocity`
# - If `return_trajectory=True`, return a list containing the initial state and every subsequent state

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def euler_flow_sample(model, x0: torch.Tensor, steps: int = 20, return_trajectory: bool = False):
    pass

# %%
# 🧪 Debug
class ConstantVelocity:
    def __call__(self, x, t):
        return torch.ones_like(x) * 2

x0 = torch.zeros(2, 3)
print(euler_flow_sample(ConstantVelocity(), x0, steps=4))

# %%
# ✅ SUBMIT
from torch_judge import check
check('euler_flow_sampler')
