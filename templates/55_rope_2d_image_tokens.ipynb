# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/55_rope_2d_image_tokens.ipynb)
#
# # 🔴 Hard: 2D RoPE for Image Tokens
#
# Implement **2D RoPE** for image patch tokens.
#
# ### Signature
# ```python
# def apply_2d_rope(x: torch.Tensor, height: int, width: int, base: float = 10000.0) -> torch.Tensor:
#     ...
# ```
#
# ### Input
# `x` has shape `(B, num_heads, height * width, head_dim)`.
#
# ### Requirements
# - `head_dim` must be divisible by 4
# - Use the first half of channels for row (`y`) rotation
# - Use the second half of channels for column (`x`) rotation
# - Preserve shape and vector norms
# - Token at position `(0, 0)` should be unchanged

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def apply_2d_rope(x: torch.Tensor, height: int, width: int, base: float = 10000.0) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
x = torch.randn(2, 4, 3 * 3, 8)
y = apply_2d_rope(x, height=3, width=3)
print(y.shape)
print("norm preserved:", torch.allclose(y.norm(dim=-1), x.norm(dim=-1), atol=1e-5))

# %%
# ✅ SUBMIT
from torch_judge import check
check('rope_2d_image_tokens')
