# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/83_async_queue_pipeline.ipynb)
#
# # 🔴 Hard: Async Queue Pipeline
#
# Implement an async queue-based worker pipeline.
#
# ### Signature
# ```python
# async def async_queue_pipeline(items, worker_fn, num_workers: int = 4) -> list:
#     ...
# ```
#
# ### Requirements
# - `worker_fn(item)` is async
# - Process items with `num_workers` async worker tasks
# - Preserve input order in the returned list
# - Shut down workers with sentinels
# - Propagate worker exceptions

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import asyncio

# %%
# ✏️ YOUR IMPLEMENTATION HERE

async def async_queue_pipeline(items, worker_fn, num_workers: int = 4):
    pass

# %%
# 🧪 Debug

def run_async(coro):
    import asyncio
    import threading
    box = {}
    def target():
        try:
            box['value'] = asyncio.run(coro)
        except BaseException as e:
            box['error'] = e
    t = threading.Thread(target=target)
    t.start()
    t.join(timeout=5)
    if t.is_alive():
        raise TimeoutError('async test timed out')
    if 'error' in box:
        raise box['error']
    return box.get('value')

async def work(x):
    await asyncio.sleep(0.01)
    return x * x
print(run_async(async_queue_pipeline(range(5), work, num_workers=2)))

# %%
# ✅ SUBMIT
from torch_judge import check
check('async_queue_pipeline')
