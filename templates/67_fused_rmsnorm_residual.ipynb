# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/67_fused_rmsnorm_residual.ipynb)
#
# # 🟡 Medium: Fused RMSNorm + Residual
#
# Implement a fused **RMSNorm + residual** helper, mirroring the logic commonly fused in LLM kernels.
#
# ### Signature
# ```python
# def fused_rmsnorm_residual(x: Tensor, residual: Tensor, weight: Tensor,
#                            eps: float = 1e-6, residual_in_fp32: bool = True) -> tuple[Tensor, Tensor]:
#     ...
# ```
#
# ### Requirements
# - Compute `updated_residual = x + residual`
# - If `residual_in_fp32=True`, do the residual accumulation and normalization in fp32
# - RMSNorm: `y = updated_residual * rsqrt(mean(updated_residual^2) + eps) * weight`
# - Return `(y, updated_residual)`

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def fused_rmsnorm_residual(x: torch.Tensor, residual: torch.Tensor, weight: torch.Tensor,
                           eps: float = 1e-6, residual_in_fp32: bool = True):
    pass

# %%
# 🧪 Debug
x = torch.randn(2, 3, 8)
r = torch.randn(2, 3, 8)
w = torch.ones(8)
y, updated = fused_rmsnorm_residual(x, r, w)
print(y.shape, updated.shape)

# %%
# ✅ SUBMIT
from torch_judge import check
check('fused_rmsnorm_residual')
