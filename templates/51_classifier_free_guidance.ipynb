# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/51_classifier_free_guidance.ipynb)
#
# # 🟡 Medium: Classifier-Free Guidance
#
# Implement **classifier-free guidance** for diffusion sampling.
#
# ### Signature
# ```python
# def classifier_free_guidance(
#     uncond: torch.Tensor,
#     cond: torch.Tensor,
#     guidance_scale: float = 7.5,
#     rescale: float = 0.0,
# ) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Core CFG formula: `uncond + guidance_scale * (cond - uncond)`
# - `guidance_scale=0` should return `uncond`
# - `guidance_scale=1` should return `cond`
# - Optional `rescale > 0` should reduce over-exposure by matching guided std to conditional std and mixing with the original guided tensor

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def classifier_free_guidance(uncond: torch.Tensor, cond: torch.Tensor,
                             guidance_scale: float = 7.5, rescale: float = 0.0) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
uncond = torch.tensor([0.0, 1.0])
cond = torch.tensor([2.0, 3.0])
print(classifier_free_guidance(uncond, cond, guidance_scale=2.0))

# %%
# ✅ SUBMIT
from torch_judge import check
check('classifier_free_guidance')
