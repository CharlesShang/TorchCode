# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/77_threaded_map_ordered.ipynb)
#
# # 🟡 Medium: Ordered Threaded Map
#
# Implement an ordered threaded map helper.
#
# ### Signature
# ```python
# def threaded_map(fn, items, max_workers: int = 4) -> list:
#     ...
# ```
#
# ### Requirements
# - Run `fn(item)` in a thread pool
# - Preserve input order in the returned list
# - Propagate exceptions raised by workers
# - Shut down the executor cleanly

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def threaded_map(fn, items, max_workers: int = 4):
    pass

# %%
# 🧪 Debug
print(threaded_map(lambda x: x * x, range(5), max_workers=2))

# %%
# ✅ SUBMIT
from torch_judge import check
check('threaded_map_ordered')
