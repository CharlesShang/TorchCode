# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/56_qk_norm_attention.ipynb)
#
# # 🟡 Medium: QK Norm Attention
#
# Implement **QK-normalized attention**, a common stability trick in modern LLM and multimodal transformer blocks.
#
# ### Signature
# ```python
# def qk_norm_attention(q: Tensor, k: Tensor, v: Tensor, mask: Tensor | None = None,
#                       eps: float = 1e-6, scale: float | None = None) -> Tensor:
#     ...
# ```
#
# ### Requirements
# - `q`: `(..., S_q, D)`, `k`: `(..., S_k, D)`, `v`: `(..., S_k, D_v)`
# - L2-normalize `q` and `k` along the last dimension
# - Default scale is `sqrt(D)`
# - Optional boolean `mask` marks valid key positions; invalid positions get `-inf`
# - Return `softmax(scores) @ v`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def qk_norm_attention(q: torch.Tensor, k: torch.Tensor, v: torch.Tensor,
                      mask: torch.Tensor | None = None, eps: float = 1e-6,
                      scale: float | None = None) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
q = torch.randn(2, 4, 5, 8)
k = torch.randn(2, 4, 6, 8)
v = torch.randn(2, 4, 6, 8)
print(qk_norm_attention(q, k, v).shape)

# %%
# ✅ SUBMIT
from torch_judge import check
check('qk_norm_attention')
