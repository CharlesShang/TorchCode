# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/79_process_pool_map.ipynb)
#
# # 🟡 Medium: Process Pool Map
#
# Implement an ordered process-pool map helper for CPU-bound work.
#
# ### Signature
# ```python
# def process_pool_map(fn, items, max_workers: int | None = None,
#                      chunksize: int = 1) -> list:
#     ...
# ```
#
# ### Requirements
# - Run `fn(item)` in a `ProcessPoolExecutor`
# - Preserve input order
# - Propagate worker exceptions
# - Use a context manager so worker processes shut down cleanly
# - The function passed in must be picklable

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
from concurrent.futures import ProcessPoolExecutor
import multiprocessing as mp

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def process_pool_map(fn, items, max_workers: int | None = None, chunksize: int = 1):
    pass

# %%
# 🧪 Debug
print(process_pool_map(abs, [-1, 2, -3], max_workers=2))

# %%
# ✅ SUBMIT
from torch_judge import check
check('process_pool_map')
