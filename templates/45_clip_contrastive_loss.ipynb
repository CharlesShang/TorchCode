# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/45_clip_contrastive_loss.ipynb)
#
# # 🟡 Medium: CLIP Contrastive Loss
#
# Implement the symmetric **CLIP / InfoNCE contrastive loss**.
#
# Given matching image and text embeddings with shape `(B, D)`:
#
# 1. L2-normalize both embedding matrices
# 2. Compute pairwise logits: `image @ text.T / temperature`
# 3. Use labels `[0, 1, ..., B-1]`, where each row should match the same-index column
# 4. Average image-to-text and text-to-image cross-entropy losses
#
# ### Signature
# ```python
# def clip_contrastive_loss(
#     image_embeds: torch.Tensor,
#     text_embeds: torch.Tensor,
#     temperature: float = 0.07,
# ) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Inputs must have the same batch size and embedding dimension
# - Return a scalar loss
# - Gradients should flow to both inputs
# - Do **NOT** use `F.cross_entropy` or `nn.CrossEntropyLoss`
# - Use a numerically stable logsumexp formulation

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn.functional as F

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def clip_contrastive_loss(image_embeds: torch.Tensor, text_embeds: torch.Tensor,
                          temperature: float = 0.07) -> torch.Tensor:
    pass  # Normalize, build logits, compute CE in both directions

# %%
# 🧪 Debug
torch.manual_seed(0)
image = torch.randn(4, 8)
text = torch.randn(4, 8)
print("Loss:", clip_contrastive_loss(image, text, temperature=0.2))

image_n = F.normalize(image, dim=-1)
text_n = F.normalize(text, dim=-1)
logits = image_n @ text_n.T / 0.2
labels = torch.arange(image.shape[0])
ref = 0.5 * (F.cross_entropy(logits, labels) + F.cross_entropy(logits.T, labels))
print("Ref: ", ref)

# %%
# ✅ SUBMIT
from torch_judge import check
check('clip_contrastive_loss')
