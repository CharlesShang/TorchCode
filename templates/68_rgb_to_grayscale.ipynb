# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/68_rgb_to_grayscale.ipynb)
#
# # 🟢 Easy: RGB to Grayscale
#
# Implement RGB to grayscale conversion for image tensors.
#
# ### Signature
# ```python
# def rgb_to_grayscale(x: torch.Tensor, keepdim: bool = True,
#                      weights: torch.Tensor | None = None) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Input shape is `(..., 3, H, W)`
# - Default luma weights are `[0.299, 0.587, 0.114]`
# - If `keepdim=True`, return shape `(..., 1, H, W)`
# - If `keepdim=False`, return shape `(..., H, W)`
# - Preserve device and dtype where possible

# %%
# Install the latest torch-judge from this repo in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q --force-reinstall --no-deps git+https://github.com/CharlesShang/TorchCode.git@master')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def rgb_to_grayscale(x: torch.Tensor, keepdim: bool = True,
                     weights: torch.Tensor | None = None) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
x = torch.rand(2, 3, 4, 4)
gray = rgb_to_grayscale(x)
print(gray.shape)

# %%
# ✅ SUBMIT
from torch_judge import check
check('rgb_to_grayscale')
