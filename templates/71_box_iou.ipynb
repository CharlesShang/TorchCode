# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/71_box_iou.ipynb)
#
# # 🟢 Easy: Bounding Box IoU
#
# Implement pairwise bounding box IoU.
#
# ### Signature
# ```python
# def box_iou(boxes1: torch.Tensor, boxes2: torch.Tensor, eps: float = 1e-7) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Boxes use `(x1, y1, x2, y2)` format
# - `boxes1`: `(N, 4)`, `boxes2`: `(M, 4)`
# - Return shape `(N, M)`
# - Clamp negative intersection widths/heights to zero

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def box_iou(boxes1: torch.Tensor, boxes2: torch.Tensor, eps: float = 1e-7) -> torch.Tensor:
    pass

# %%
# 🧪 Debug
b1 = torch.tensor([[0., 0., 2., 2.]])
b2 = torch.tensor([[1., 1., 3., 3.]])
print(box_iou(b1, b2))

# %%
# ✅ SUBMIT
from torch_judge import check
check('box_iou')
