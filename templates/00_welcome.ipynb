# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/00_welcome.ipynb)
#
# # 🔥 TorchCode — PyTorch Operator Practice
#
# Welcome! This is a JupyterLab-based environment for practicing PyTorch operator implementations.
#
# ## 📁 File Layout
#
# Each problem has **two** notebooks:
#
# | File | Description |
# |------|-------------|
# | `01_relu.ipynb` | ✏️ **Blank template** — write your implementation here |
# | `01_relu_solution.ipynb` | 📖 **Reference solution** — check when you're stuck |
#
# ## How to Use
#
# 1. **Open a problem** — pick a blank template like `01_relu.ipynb`
# 2. **Read the description** — the first cell has the problem statement and signature
# 3. **Write your code** — implement in the `✏️ YOUR IMPLEMENTATION HERE` cell
# 4. **Debug** — insert cells freely for `print(x.shape)` etc.
# 5. **Submit** — run the last cell `check("relu")` to see results
# 6. **Stuck?** — call `hint("relu")` for a nudge, or open the `_solution.ipynb`
# 7. **Reset** — click the 🔄 **Reset** button in the toolbar to restore the blank template and practice again
#
# > 💡 Every notebook also has a **Colab** toolbar button and an **Open in Colab** badge — use them to run problems in Google Colab with zero setup.
#
# ## Quick Start
#
# 📖 **Reference solutions in Colab**: [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/01_relu_solution.ipynb) — Start with ReLU. Or use the **Colab** links in the table below for each solution.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
from torch_judge import status
status()

# %% [markdown]
# ## Problem List (83 problems)
#
# ### 🧱 Fundamentals — "Implement X from scratch"
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 1 | ReLU | 🟢 Easy | [Open](01_relu.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/01_relu.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/01_relu.ipynb" target="_blank">Colab</a> | [Open](01_relu_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/01_relu_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/01_relu_solution.ipynb" target="_blank">Colab</a> |
# | 2 | Softmax | 🟢 Easy | [Open](02_softmax.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/02_softmax.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/02_softmax.ipynb" target="_blank">Colab</a> | [Open](02_softmax_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/02_softmax_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/02_softmax_solution.ipynb" target="_blank">Colab</a> |
# | 16 | Cross-Entropy Loss | 🟢 Easy | [Open](16_cross_entropy.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/16_cross_entropy.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/16_cross_entropy.ipynb" target="_blank">Colab</a> | [Open](16_cross_entropy_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/16_cross_entropy_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/16_cross_entropy_solution.ipynb" target="_blank">Colab</a> |
# | 42 | Label Smoothing Loss | 🟡 Medium | [Open](42_label_smoothing.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/42_label_smoothing.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/42_label_smoothing.ipynb" target="_blank">Colab</a> | [Open](42_label_smoothing_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/42_label_smoothing_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/42_label_smoothing_solution.ipynb" target="_blank">Colab</a> |
# | 17 | Dropout | 🟢 Easy | [Open](17_dropout.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/17_dropout.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/17_dropout.ipynb" target="_blank">Colab</a> | [Open](17_dropout_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/17_dropout_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/17_dropout_solution.ipynb" target="_blank">Colab</a> |
# | 18 | Embedding | 🟢 Easy | [Open](18_embedding.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/18_embedding.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/18_embedding.ipynb" target="_blank">Colab</a> | [Open](18_embedding_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/18_embedding_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/18_embedding_solution.ipynb" target="_blank">Colab</a> |
# | 19 | GELU | 🟢 Easy | [Open](19_gelu.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/19_gelu.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/19_gelu.ipynb" target="_blank">Colab</a> | [Open](19_gelu_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/19_gelu_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/19_gelu_solution.ipynb" target="_blank">Colab</a> |
# | 20 | Kaiming Init | 🟢 Easy | [Open](20_weight_init.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/20_weight_init.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/20_weight_init.ipynb" target="_blank">Colab</a> | [Open](20_weight_init_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/20_weight_init_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/20_weight_init_solution.ipynb" target="_blank">Colab</a> |
# | 21 | Gradient Clipping | 🟢 Easy | [Open](21_gradient_clipping.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/21_gradient_clipping.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/21_gradient_clipping.ipynb" target="_blank">Colab</a> | [Open](21_gradient_clipping_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/21_gradient_clipping_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/21_gradient_clipping_solution.ipynb" target="_blank">Colab</a> |
# | 31 | Gradient Accumulation | 🟢 Easy | [Open](31_gradient_accumulation.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/31_gradient_accumulation.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/31_gradient_accumulation.ipynb" target="_blank">Colab</a> | [Open](31_gradient_accumulation_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/31_gradient_accumulation_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/31_gradient_accumulation_solution.ipynb" target="_blank">Colab</a> |
# | 3 | Linear Layer | 🟡 Medium | [Open](03_linear.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/03_linear.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/03_linear.ipynb" target="_blank">Colab</a> | [Open](03_linear_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/03_linear_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/03_linear_solution.ipynb" target="_blank">Colab</a> |
# | 4 | LayerNorm | 🟡 Medium | [Open](04_layernorm.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/04_layernorm.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/04_layernorm.ipynb" target="_blank">Colab</a> | [Open](04_layernorm_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/04_layernorm_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/04_layernorm_solution.ipynb" target="_blank">Colab</a> |
# | 7 | BatchNorm | 🟡 Medium | [Open](07_batchnorm.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/07_batchnorm.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/07_batchnorm.ipynb" target="_blank">Colab</a> | [Open](07_batchnorm_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/07_batchnorm_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/07_batchnorm_solution.ipynb" target="_blank">Colab</a> |
# | 8 | RMSNorm | 🟡 Medium | [Open](08_rmsnorm.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/08_rmsnorm.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/08_rmsnorm.ipynb" target="_blank">Colab</a> | [Open](08_rmsnorm_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/08_rmsnorm_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/08_rmsnorm_solution.ipynb" target="_blank">Colab</a> |
# | 15 | SwiGLU MLP | 🟡 Medium | [Open](15_mlp.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/15_mlp.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/15_mlp.ipynb" target="_blank">Colab</a> | [Open](15_mlp_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/15_mlp_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/15_mlp_solution.ipynb" target="_blank">Colab</a> |
# | 22 | Conv2d | 🟡 Medium | [Open](22_conv2d.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/22_conv2d.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/22_conv2d.ipynb" target="_blank">Colab</a> | [Open](22_conv2d_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/22_conv2d_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/22_conv2d_solution.ipynb" target="_blank">Colab</a> |
# | 41 | MaxPool2d | 🟡 Medium | [Open](41_max_pool2d.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/41_max_pool2d.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/41_max_pool2d.ipynb" target="_blank">Colab</a> | [Open](41_max_pool2d_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/41_max_pool2d_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/41_max_pool2d_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🧠 Attention Mechanisms
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 23 | Cross-Attention | 🟡 Medium | [Open](23_cross_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/23_cross_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/23_cross_attention.ipynb" target="_blank">Colab</a> | [Open](23_cross_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/23_cross_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/23_cross_attention_solution.ipynb" target="_blank">Colab</a> |
# | 5 | Scaled Dot-Product Attention | 🔴 Hard | [Open](05_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/05_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/05_attention.ipynb" target="_blank">Colab</a> | [Open](05_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/05_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/05_attention_solution.ipynb" target="_blank">Colab</a> |
# | 6 | Multi-Head Attention | 🔴 Hard | [Open](06_multihead_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/06_multihead_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/06_multihead_attention.ipynb" target="_blank">Colab</a> | [Open](06_multihead_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/06_multihead_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/06_multihead_attention_solution.ipynb" target="_blank">Colab</a> |
# | 9 | Causal Self-Attention | 🔴 Hard | [Open](09_causal_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/09_causal_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/09_causal_attention.ipynb" target="_blank">Colab</a> | [Open](09_causal_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/09_causal_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/09_causal_attention_solution.ipynb" target="_blank">Colab</a> |
# | 10 | Grouped Query Attention | 🔴 Hard | [Open](10_gqa.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/10_gqa.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/10_gqa.ipynb" target="_blank">Colab</a> | [Open](10_gqa_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/10_gqa_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/10_gqa_solution.ipynb" target="_blank">Colab</a> |
# | 11 | Sliding Window Attention | 🔴 Hard | [Open](11_sliding_window.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/11_sliding_window.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/11_sliding_window.ipynb" target="_blank">Colab</a> | [Open](11_sliding_window_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/11_sliding_window_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/11_sliding_window_solution.ipynb" target="_blank">Colab</a> |
# | 12 | Linear Attention | 🔴 Hard | [Open](12_linear_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/12_linear_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/12_linear_attention.ipynb" target="_blank">Colab</a> | [Open](12_linear_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/12_linear_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/12_linear_attention_solution.ipynb" target="_blank">Colab</a> |
# | 14 | KV Cache Attention | 🔴 Hard | [Open](14_kv_cache.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/14_kv_cache.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/14_kv_cache.ipynb" target="_blank">Colab</a> | [Open](14_kv_cache_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/14_kv_cache_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/14_kv_cache_solution.ipynb" target="_blank">Colab</a> |
# | 24 | RoPE | 🔴 Hard | [Open](24_rope.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/24_rope.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/24_rope.ipynb" target="_blank">Colab</a> | [Open](24_rope_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/24_rope_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/24_rope_solution.ipynb" target="_blank">Colab</a> |
# | 25 | Flash Attention | 🔴 Hard | [Open](25_flash_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/25_flash_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/25_flash_attention.ipynb" target="_blank">Colab</a> | [Open](25_flash_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/25_flash_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/25_flash_attention_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🏗️ Architecture & Adaptation
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 26 | LoRA | 🟡 Medium | [Open](26_lora.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/26_lora.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/26_lora.ipynb" target="_blank">Colab</a> | [Open](26_lora_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/26_lora_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/26_lora_solution.ipynb" target="_blank">Colab</a> |
# | 27 | ViT Patch Embedding | 🟡 Medium | [Open](27_vit_patch.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/27_vit_patch.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/27_vit_patch.ipynb" target="_blank">Colab</a> | [Open](27_vit_patch_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/27_vit_patch_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/27_vit_patch_solution.ipynb" target="_blank">Colab</a> |
# | 43 | Sinusoidal Positional Encoding | 🟡 Medium | [Open](43_sinusoidal_positional_encoding.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/43_sinusoidal_positional_encoding.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/43_sinusoidal_positional_encoding.ipynb" target="_blank">Colab</a> | [Open](43_sinusoidal_positional_encoding_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/43_sinusoidal_positional_encoding_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/43_sinusoidal_positional_encoding_solution.ipynb" target="_blank">Colab</a> |
# | 13 | GPT-2 Block | 🔴 Hard | [Open](13_gpt2_block.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/13_gpt2_block.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/13_gpt2_block.ipynb" target="_blank">Colab</a> | [Open](13_gpt2_block_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/13_gpt2_block_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/13_gpt2_block_solution.ipynb" target="_blank">Colab</a> |
# | 28 | Mixture of Experts | 🔴 Hard | [Open](28_moe.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/28_moe.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/28_moe.ipynb" target="_blank">Colab</a> | [Open](28_moe_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/28_moe_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/28_moe_solution.ipynb" target="_blank">Colab</a> |
#
# ### ⚙️ Training & Optimization
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 29 | Adam Optimizer | 🟡 Medium | [Open](29_adam.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/29_adam.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/29_adam.ipynb" target="_blank">Colab</a> | [Open](29_adam_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/29_adam_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/29_adam_solution.ipynb" target="_blank">Colab</a> |
# | 44 | SGD with Momentum | 🟡 Medium | [Open](44_sgd_momentum.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/44_sgd_momentum.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/44_sgd_momentum.ipynb" target="_blank">Colab</a> | [Open](44_sgd_momentum_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/44_sgd_momentum_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/44_sgd_momentum_solution.ipynb" target="_blank">Colab</a> |
# | 30 | Cosine LR Scheduler | 🟡 Medium | [Open](30_cosine_lr.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/30_cosine_lr.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/30_cosine_lr.ipynb" target="_blank">Colab</a> | [Open](30_cosine_lr_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/30_cosine_lr_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/30_cosine_lr_solution.ipynb" target="_blank">Colab</a> |
# | 40 | Linear Regression | 🟡 Medium | [Open](40_linear_regression.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/40_linear_regression.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/40_linear_regression.ipynb" target="_blank">Colab</a> | [Open](40_linear_regression_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/40_linear_regression_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/40_linear_regression_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🎯 Inference & Decoding
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 32 | Top-k / Top-p Sampling | 🟡 Medium | [Open](32_topk_sampling.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/32_topk_sampling.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/32_topk_sampling.ipynb" target="_blank">Colab</a> | [Open](32_topk_sampling_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/32_topk_sampling_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/32_topk_sampling_solution.ipynb" target="_blank">Colab</a> |
# | 33 | Beam Search | 🟡 Medium | [Open](33_beam_search.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/33_beam_search.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/33_beam_search.ipynb" target="_blank">Colab</a> | [Open](33_beam_search_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/33_beam_search_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/33_beam_search_solution.ipynb" target="_blank">Colab</a> |
# | 34 | Speculative Decoding | 🔴 Hard | [Open](34_speculative_decoding.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/34_speculative_decoding.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/34_speculative_decoding.ipynb" target="_blank">Colab</a> | [Open](34_speculative_decoding_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/34_speculative_decoding_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/34_speculative_decoding_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🔬 Advanced
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 35 | BPE Tokenizer | 🔴 Hard | [Open](35_bpe.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/35_bpe.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/35_bpe.ipynb" target="_blank">Colab</a> | [Open](35_bpe_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/35_bpe_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/35_bpe_solution.ipynb" target="_blank">Colab</a> |
# | 36 | INT8 Quantization | 🔴 Hard | [Open](36_int8_quantization.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/36_int8_quantization.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/36_int8_quantization.ipynb" target="_blank">Colab</a> | [Open](36_int8_quantization_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/36_int8_quantization_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/36_int8_quantization_solution.ipynb" target="_blank">Colab</a> |
# | 45 | CLIP Contrastive Loss | 🟡 Medium | [Open](45_clip_contrastive_loss.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/45_clip_contrastive_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/45_clip_contrastive_loss.ipynb" target="_blank">Colab</a> | [Open](45_clip_contrastive_loss_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/45_clip_contrastive_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/45_clip_contrastive_loss_solution.ipynb" target="_blank">Colab</a> |
# | 37 | DPO Loss | 🔴 Hard | [Open](37_dpo_loss.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/37_dpo_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/37_dpo_loss.ipynb" target="_blank">Colab</a> | [Open](37_dpo_loss_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/37_dpo_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/37_dpo_loss_solution.ipynb" target="_blank">Colab</a> |
# | 38 | GRPO Loss | 🔴 Hard | [Open](38_grpo_loss.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/38_grpo_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/38_grpo_loss.ipynb" target="_blank">Colab</a> | [Open](38_grpo_loss_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/38_grpo_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/38_grpo_loss_solution.ipynb" target="_blank">Colab</a> |
# | 39 | PPO Loss | 🔴 Hard | [Open](39_ppo_loss.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/39_ppo_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/39_ppo_loss.ipynb" target="_blank">Colab</a> | [Open](39_ppo_loss_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/39_ppo_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/39_ppo_loss_solution.ipynb" target="_blank">Colab</a> |
#
# ## Useful Commands
#
# ```python
# from torch_judge import check, hint, status
#
# status()                   # Progress dashboard
# check("relu")              # Judge your implementation
# hint("causal_attention")   # Get a hint
# ```
#
# ### 🖼️ MMDiT & Diffusion Transformers
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 46 | Patchify / Unpatchify Latents | 🟡 Medium | [Open](46_patchify_latents.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/46_patchify_latents.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/46_patchify_latents.ipynb" target="_blank">Colab</a> | [Open](46_patchify_latents_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/46_patchify_latents_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/46_patchify_latents_solution.ipynb" target="_blank">Colab</a> |
# | 47 | Diffusion Timestep Embedding | 🟢 Easy | [Open](47_timestep_embedding.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/47_timestep_embedding.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/47_timestep_embedding.ipynb" target="_blank">Colab</a> | [Open](47_timestep_embedding_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/47_timestep_embedding_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/47_timestep_embedding_solution.ipynb" target="_blank">Colab</a> |
# | 48 | AdaLN-Zero Modulation | 🟡 Medium | [Open](48_adaln_zero_modulation.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/48_adaln_zero_modulation.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/48_adaln_zero_modulation.ipynb" target="_blank">Colab</a> | [Open](48_adaln_zero_modulation_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/48_adaln_zero_modulation_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/48_adaln_zero_modulation_solution.ipynb" target="_blank">Colab</a> |
# | 49 | DiT Block | 🔴 Hard | [Open](49_dit_block.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/49_dit_block.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/49_dit_block.ipynb" target="_blank">Colab</a> | [Open](49_dit_block_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/49_dit_block_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/49_dit_block_solution.ipynb" target="_blank">Colab</a> |
# | 50 | MMDiT Joint Attention | 🔴 Hard | [Open](50_mmdit_joint_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/50_mmdit_joint_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/50_mmdit_joint_attention.ipynb" target="_blank">Colab</a> | [Open](50_mmdit_joint_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/50_mmdit_joint_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/50_mmdit_joint_attention_solution.ipynb" target="_blank">Colab</a> |
# | 51 | Classifier-Free Guidance | 🟡 Medium | [Open](51_classifier_free_guidance.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/51_classifier_free_guidance.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/51_classifier_free_guidance.ipynb" target="_blank">Colab</a> | [Open](51_classifier_free_guidance_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/51_classifier_free_guidance_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/51_classifier_free_guidance_solution.ipynb" target="_blank">Colab</a> |
# | 52 | Rectified Flow Loss | 🟡 Medium | [Open](52_rectified_flow_loss.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/52_rectified_flow_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/52_rectified_flow_loss.ipynb" target="_blank">Colab</a> | [Open](52_rectified_flow_loss_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/52_rectified_flow_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/52_rectified_flow_loss_solution.ipynb" target="_blank">Colab</a> |
# | 53 | Euler Flow Sampler | 🟡 Medium | [Open](53_euler_flow_sampler.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/53_euler_flow_sampler.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/53_euler_flow_sampler.ipynb" target="_blank">Colab</a> | [Open](53_euler_flow_sampler_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/53_euler_flow_sampler_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/53_euler_flow_sampler_solution.ipynb" target="_blank">Colab</a> |
# | 54 | Logit-Normal Timestep Sampling | 🟡 Medium | [Open](54_logit_normal_timestep_sampling.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/54_logit_normal_timestep_sampling.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/54_logit_normal_timestep_sampling.ipynb" target="_blank">Colab</a> | [Open](54_logit_normal_timestep_sampling_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/54_logit_normal_timestep_sampling_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/54_logit_normal_timestep_sampling_solution.ipynb" target="_blank">Colab</a> |
# | 55 | 2D RoPE for Image Tokens | 🔴 Hard | [Open](55_rope_2d_image_tokens.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/55_rope_2d_image_tokens.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/55_rope_2d_image_tokens.ipynb" target="_blank">Colab</a> | [Open](55_rope_2d_image_tokens_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/55_rope_2d_image_tokens_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/55_rope_2d_image_tokens_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🧬 Modern LLM Systems & Architecture
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 56 | QK Norm Attention | 🟡 Medium | [Open](56_qk_norm_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/56_qk_norm_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/56_qk_norm_attention.ipynb" target="_blank">Colab</a> | [Open](56_qk_norm_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/56_qk_norm_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/56_qk_norm_attention_solution.ipynb" target="_blank">Colab</a> |
# | 57 | RoPE Scaling | 🟡 Medium | [Open](57_rope_scaling.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/57_rope_scaling.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/57_rope_scaling.ipynb" target="_blank">Colab</a> | [Open](57_rope_scaling_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/57_rope_scaling_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/57_rope_scaling_solution.ipynb" target="_blank">Colab</a> |
# | 58 | Multi-Head Latent Attention | 🔴 Hard | [Open](58_multi_head_latent_attention.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/58_multi_head_latent_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/58_multi_head_latent_attention.ipynb" target="_blank">Colab</a> | [Open](58_multi_head_latent_attention_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/58_multi_head_latent_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/58_multi_head_latent_attention_solution.ipynb" target="_blank">Colab</a> |
# | 59 | Paged KV Cache | 🔴 Hard | [Open](59_paged_kv_cache.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/59_paged_kv_cache.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/59_paged_kv_cache.ipynb" target="_blank">Colab</a> | [Open](59_paged_kv_cache_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/59_paged_kv_cache_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/59_paged_kv_cache_solution.ipynb" target="_blank">Colab</a> |
# | 60 | Prefix Cache | 🟡 Medium | [Open](60_prefix_cache.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/60_prefix_cache.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/60_prefix_cache.ipynb" target="_blank">Colab</a> | [Open](60_prefix_cache_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/60_prefix_cache_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/60_prefix_cache_solution.ipynb" target="_blank">Colab</a> |
# | 61 | Continuous Batching Scheduler | 🔴 Hard | [Open](61_continuous_batching_scheduler.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/61_continuous_batching_scheduler.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/61_continuous_batching_scheduler.ipynb" target="_blank">Colab</a> | [Open](61_continuous_batching_scheduler_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/61_continuous_batching_scheduler_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/61_continuous_batching_scheduler_solution.ipynb" target="_blank">Colab</a> |
# | 62 | Speculative Decoding with Verification | 🔴 Hard | [Open](62_speculative_decoding_verification.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/62_speculative_decoding_verification.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/62_speculative_decoding_verification.ipynb" target="_blank">Colab</a> | [Open](62_speculative_decoding_verification_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/62_speculative_decoding_verification_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/62_speculative_decoding_verification_solution.ipynb" target="_blank">Colab</a> |
# | 63 | Multi-Token Prediction Loss | 🟡 Medium | [Open](63_multi_token_prediction_loss.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/63_multi_token_prediction_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/63_multi_token_prediction_loss.ipynb" target="_blank">Colab</a> | [Open](63_multi_token_prediction_loss_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/63_multi_token_prediction_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/63_multi_token_prediction_loss_solution.ipynb" target="_blank">Colab</a> |
# | 64 | QLoRA NF4 Quantization | 🔴 Hard | [Open](64_qlora_nf4_quantization.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/64_qlora_nf4_quantization.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/64_qlora_nf4_quantization.ipynb" target="_blank">Colab</a> | [Open](64_qlora_nf4_quantization_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/64_qlora_nf4_quantization_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/64_qlora_nf4_quantization_solution.ipynb" target="_blank">Colab</a> |
# | 65 | FP8 Quantization Basics | 🟡 Medium | [Open](65_fp8_quantization.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/65_fp8_quantization.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/65_fp8_quantization.ipynb" target="_blank">Colab</a> | [Open](65_fp8_quantization_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/65_fp8_quantization_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/65_fp8_quantization_solution.ipynb" target="_blank">Colab</a> |
# | 66 | LoRA Merge / Unmerge | 🟡 Medium | [Open](66_lora_merge_unmerge.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/66_lora_merge_unmerge.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/66_lora_merge_unmerge.ipynb" target="_blank">Colab</a> | [Open](66_lora_merge_unmerge_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/66_lora_merge_unmerge_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/66_lora_merge_unmerge_solution.ipynb" target="_blank">Colab</a> |
# | 67 | Fused RMSNorm + Residual | 🟡 Medium | [Open](67_fused_rmsnorm_residual.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/67_fused_rmsnorm_residual.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/67_fused_rmsnorm_residual.ipynb" target="_blank">Colab</a> | [Open](67_fused_rmsnorm_residual_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/67_fused_rmsnorm_residual_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/67_fused_rmsnorm_residual_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🖼️ Image & Video Processing
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 68 | RGB to Grayscale | 🟢 Easy | [Open](68_rgb_to_grayscale.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/68_rgb_to_grayscale.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/68_rgb_to_grayscale.ipynb" target="_blank">Colab</a> | [Open](68_rgb_to_grayscale_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/68_rgb_to_grayscale_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/68_rgb_to_grayscale_solution.ipynb" target="_blank">Colab</a> |
# | 69 | Bilinear Resize NCHW | 🟡 Medium | [Open](69_bilinear_resize.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/69_bilinear_resize.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/69_bilinear_resize.ipynb" target="_blank">Colab</a> | [Open](69_bilinear_resize_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/69_bilinear_resize_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/69_bilinear_resize_solution.ipynb" target="_blank">Colab</a> |
# | 70 | Sobel Edge Magnitude | 🟡 Medium | [Open](70_sobel_edges.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/70_sobel_edges.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/70_sobel_edges.ipynb" target="_blank">Colab</a> | [Open](70_sobel_edges_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/70_sobel_edges_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/70_sobel_edges_solution.ipynb" target="_blank">Colab</a> |
# | 71 | Bounding Box IoU | 🟢 Easy | [Open](71_box_iou.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/71_box_iou.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/71_box_iou.ipynb" target="_blank">Colab</a> | [Open](71_box_iou_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/71_box_iou_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/71_box_iou_solution.ipynb" target="_blank">Colab</a> |
# | 72 | Non-Max Suppression | 🟡 Medium | [Open](72_non_max_suppression.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/72_non_max_suppression.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/72_non_max_suppression.ipynb" target="_blank">Colab</a> | [Open](72_non_max_suppression_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/72_non_max_suppression_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/72_non_max_suppression_solution.ipynb" target="_blank">Colab</a> |
# | 73 | Video Uniform Temporal Sampling | 🟡 Medium | [Open](73_video_uniform_temporal_sample.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/73_video_uniform_temporal_sample.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/73_video_uniform_temporal_sample.ipynb" target="_blank">Colab</a> | [Open](73_video_uniform_temporal_sample_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/73_video_uniform_temporal_sample_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/73_video_uniform_temporal_sample_solution.ipynb" target="_blank">Colab</a> |
# | 74 | Temporal Average Pooling for Video | 🟡 Medium | [Open](74_temporal_average_pool.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/74_temporal_average_pool.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/74_temporal_average_pool.ipynb" target="_blank">Colab</a> | [Open](74_temporal_average_pool_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/74_temporal_average_pool_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/74_temporal_average_pool_solution.ipynb" target="_blank">Colab</a> |
# | 75 | Video Tubelet Patchify | 🔴 Hard | [Open](75_video_tubelet_patchify.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/75_video_tubelet_patchify.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/75_video_tubelet_patchify.ipynb" target="_blank">Colab</a> | [Open](75_video_tubelet_patchify_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/75_video_tubelet_patchify_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/75_video_tubelet_patchify_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🧵 Python Concurrency
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 76 | Thread-Safe Counter | 🟢 Easy | [Open](76_thread_safe_counter.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/76_thread_safe_counter.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/76_thread_safe_counter.ipynb" target="_blank">Colab</a> | [Open](76_thread_safe_counter_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/76_thread_safe_counter_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/76_thread_safe_counter_solution.ipynb" target="_blank">Colab</a> |
# | 77 | Ordered Threaded Map | 🟡 Medium | [Open](77_threaded_map_ordered.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/77_threaded_map_ordered.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/77_threaded_map_ordered.ipynb" target="_blank">Colab</a> | [Open](77_threaded_map_ordered_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/77_threaded_map_ordered_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/77_threaded_map_ordered_solution.ipynb" target="_blank">Colab</a> |
# | 78 | Bounded Blocking Queue | 🟡 Medium | [Open](78_bounded_blocking_queue.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/78_bounded_blocking_queue.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/78_bounded_blocking_queue.ipynb" target="_blank">Colab</a> | [Open](78_bounded_blocking_queue_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/78_bounded_blocking_queue_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/78_bounded_blocking_queue_solution.ipynb" target="_blank">Colab</a> |
# | 79 | Process Pool Map | 🟡 Medium | [Open](79_process_pool_map.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/79_process_pool_map.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/79_process_pool_map.ipynb" target="_blank">Colab</a> | [Open](79_process_pool_map_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/79_process_pool_map_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/79_process_pool_map_solution.ipynb" target="_blank">Colab</a> |
# | 80 | Async Gather with Concurrency Limit | 🟡 Medium | [Open](80_async_gather_limited.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/80_async_gather_limited.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/80_async_gather_limited.ipynb" target="_blank">Colab</a> | [Open](80_async_gather_limited_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/80_async_gather_limited_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/80_async_gather_limited_solution.ipynb" target="_blank">Colab</a> |
# | 81 | Async Gather with Timeout Defaults | 🟡 Medium | [Open](81_async_timeout_gather.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/81_async_timeout_gather.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/81_async_timeout_gather.ipynb" target="_blank">Colab</a> | [Open](81_async_timeout_gather_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/81_async_timeout_gather_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/81_async_timeout_gather_solution.ipynb" target="_blank">Colab</a> |
# | 82 | Async Retry Helper | 🟡 Medium | [Open](82_async_retry.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/82_async_retry.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/82_async_retry.ipynb" target="_blank">Colab</a> | [Open](82_async_retry_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/82_async_retry_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/82_async_retry_solution.ipynb" target="_blank">Colab</a> |
# | 83 | Async Queue Pipeline | 🔴 Hard | [Open](83_async_queue_pipeline.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/templates/83_async_queue_pipeline.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/templates/83_async_queue_pipeline.ipynb" target="_blank">Colab</a> | [Open](83_async_queue_pipeline_solution.ipynb) · <a href="https://github.com/CharlesShang/TorchCode/blob/master/solutions/83_async_queue_pipeline_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/CharlesShang/TorchCode/blob/master/solutions/83_async_queue_pipeline_solution.ipynb" target="_blank">Colab</a> |
