# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/43_sinusoidal_positional_encoding.ipynb)
#
# # 🟡 Medium: Sinusoidal Positional Encoding
#
# Implement the original Transformer **sinusoidal positional encoding**.
#
# For position `pos` and channel pair index `i`:
#
# $$PE(pos, 2i) = \sin\left(pos / base^{2i / d}
# ight)$$
# $$PE(pos, 2i + 1) = \cos\left(pos / base^{2i / d}
# ight)$$
#
# ### Signature
# ```python
# def sinusoidal_positional_encoding(
#     seq_len: int,
#     dim: int,
#     base: float = 10000.0,
#     device=None,
#     dtype=torch.float32,
# ) -> torch.Tensor:
#     ...
# ```
#
# ### Requirements
# - Return shape `(seq_len, dim)`
# - Support odd `dim` values
# - Preserve the requested `device` and `dtype`
# - The returned tensor should not require gradients by default
# - Do **NOT** use `nn.Embedding` or learned parameters

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def sinusoidal_positional_encoding(seq_len: int, dim: int, base: float = 10000.0,
                                   device=None, dtype=torch.float32) -> torch.Tensor:
    pass  # Build (seq_len, dim) with sin on even columns and cos on odd columns

# %%
# 🧪 Debug
pe = sinusoidal_positional_encoding(seq_len=4, dim=6)
print(pe)
print("Shape:", pe.shape)
print("First row:", pe[0])  # even columns 0, odd columns 1

# %%
# ✅ SUBMIT
from torch_judge import check
check('sinusoidal_positional_encoding')
